# %%
import pandas as pd
import numpy as np
import os
import shap
import json
import matplotlib.pyplot as plt

from dataloader.dataset import Dataset
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
results_dir = "/Volumes/methlab/Students/Jonathan/results/runs/2024_kw34/20240821_0753_5ff6_feature_sets_cv/20240821_0816_manual_linguistic_features_gpt_v6_7steps_literature_slnu"

# %%
shap_values_raw = np.load(os.path.join(results_dir, "shap_values.npy"))

# %%
test_data = Dataset.from_disk(os.path.join(results_dir, "dataset")).data
feature_names = test_data.columns.tolist()
feature_names
# Out:
# Created object of class <class 'dataloader.dataset.TabularDataset'>: Dataset Concatenate(ADReSS manual transcripts (train) - Linguistic Features, ADReSS manual transcripts (test) - Linguistic Features) with variables [('data', (156, 45)), ('sample_names', (156,)), ('labels', (156,))], config ({'preprocessors': ['Linguistic Features'], 'debug': False, 'cv_shuffler': <dataloader.cv_shuffler.ADReSSCrossValidationShuffler object at 0x288e16a90>, 'transcript_config': {'only_PAR': True, 'keep_pauses': False, 'keep_terminators': True, 'keep_unintelligable_speech': False, 'insert_pauses_automatic': False}, 'transcript_config_hash': 'ee5faf'})
# ['lit_pronoun_noun_ratio',
#  'lit_verb_noun_ratio',
#  'lit_subordinate_coordinate_conjunction_ratio',
#  'lit_adverb_ratio',
#  'lit_noun_ratio',
#  'lit_verb_ratio',
#  'lit_pronoun_ratio',
#  'lit_personal_pronoun_ratio',
#  'lit_determiner_ratio',
#  'lit_preposition_ratio',
#  'lit_verb_present_participle_ratio',
#  'lit_verb_modal_ratio',
#  'lit_verb_third_person_singular_ratio',
#  'lit_NP -> PRP',
#  'lit_ADVP -> RB',
#  'lit_NP -> DT_NN',
#  'lit_ROOT -> FRAG',
#  'lit_VP -> VBG',
#  'lit_VP -> VBG_PP',
#  'lit_VP -> VBD_NP',
#  'lit_INTJ -> UH',
#  'lit_NP_ratio',
#  'lit_PRP_ratio',
#  'lit_PP_ratio',
#  'lit_VP_ratio',
#  'lit_avg_n_words_in_NP',
#  'lit_n_words',
#  'lit_n_unique_words',
#  'lit_avg_word_length',
#  'lit_avg_sentence_length',
#  'lit_words_not_in_dict_ratio',
#  'lit_brunets_index',
#  'lit_honores_statistic',
#  'lit_ttr',
#  'lit_mattr',
#  'lit_flesch_kincaid',
#  'lit_avg_distance_between_utterances',
#  'lit_prop_utterance_dist_below_05',
#  'lit_propositional_density',
#  'lit_content_density',
#  'Semantic Paraphasias',
#  'Impoverished Vocabulary',
#  'Discourse Impairment',
#  'Word-Finding Difficulties (Anomia)',
#  'Syntactic Simplification']

# %%
from matplotlib import rc, font_manager
rc('font',**{'family':'serif','serif':['Times']})

shap.summary_plot(shap_values_raw, test_data, plot_size=(5,5), max_display=10, feature_names=[c for c in test_data.columns], show=False)
plt.tight_layout()
csfont = {'fontname':'Times', 'size':14}

ax = plt.gca()
#ax.set_xlabel(ax.xaxis.get_label().get_text(), loc="right", **csfont) 
#for label in ax.get_yticklabels():
#    label.set_fontproperties({'family': 'Times', 'size': 14})
plt.savefig("plots/feature_importance_shap.pdf")
plt.show()

# %%
shap_values = pd.DataFrame(shap_values_raw, columns=test_data.columns)
shap_values
# Out:
#      lit_pronoun_noun_ratio  lit_verb_noun_ratio  \
# 0                 -0.010831            -0.001793
# 1                  0.010790             0.000807
# 2                 -0.002288            -0.000828
# 3                 -0.008949            -0.003066
# 4                 -0.010947            -0.004365
# ..                      ...                  ...
# 151                0.020509             0.004730
# 152               -0.011475            -0.003656
# 153               -0.005018             0.009756
# 154               -0.006108            -0.003460
# 155                0.017806            -0.001843
#
#      lit_subordinate_coordinate_conjunction_ratio  lit_adverb_ratio  \
# 0                                       -0.000377         -0.004094
# 1                                       -0.000203          0.049610
# 2                                       -0.000934         -0.000364
# 3                                        0.001133          0.006934
# 4                                       -0.000780         -0.029062
# ..                                            ...               ...
# 151                                     -0.000390          0.040038
# 152                                     -0.001447         -0.016271
# 153                                     -0.001556         -0.011027
# 154                                      0.000515         -0.022400
# 155                                     -0.001432         -0.022589
#
#      lit_noun_ratio  lit_verb_ratio  lit_pronoun_ratio  \
# 0         -0.007960        0.004953          -0.008704
# 1          0.014910        0.004333          -0.007609
# 2         -0.012830        0.006153          -0.002509
# 3         -0.015769        0.004530          -0.007049
# 4         -0.018892        0.007479          -0.005951
# ..              ...             ...                ...
# 151        0.017120        0.000217           0.006807
# 152        0.003761       -0.001544          -0.006940
# 153        0.017245       -0.007957          -0.002390
# 154        0.012235       -0.009291          -0.004435
# 155        0.027827       -0.002305           0.017153
#
#      lit_personal_pronoun_ratio  lit_determiner_ratio  lit_preposition_ratio  \
# 0                     -0.020324             -0.010440               0.012629
# 1                     -0.007175             -0.002285               0.005433
# 2                     -0.003182              0.003108              -0.002416
# 3                     -0.009271             -0.000049               0.000531
# 4                     -0.026464             -0.004612               0.001963
# ..                          ...                   ...                    ...
# 151                    0.027318              0.016360               0.003549
# 152                   -0.018384             -0.003577              -0.006030
# 153                   -0.011841             -0.008395              -0.003624
# 154                    0.004742              0.003406               0.016227
# 155                    0.073337              0.002352              -0.001363
#
#      ...  lit_flesch_kincaid  lit_avg_distance_between_utterances  \
# 0    ...            0.076615                             0.037192
# 1    ...           -0.011285                             0.002729
# 2    ...            0.012396                             0.007953
# 3    ...            0.018425                            -0.000127
# 4    ...            0.059420                            -0.006161
# ..   ...                 ...                                  ...
# 151  ...            0.024356                            -0.002801
# 152  ...           -0.014912                            -0.006697
# 153  ...           -0.019270                            -0.006488
# 154  ...           -0.010946                            -0.009503
# 155  ...           -0.017648                             0.001840
#
#      lit_prop_utterance_dist_below_05  lit_propositional_density  \
# 0                            0.002457                  -0.005320
# 1                           -0.000766                  -0.004414
# 2                            0.008300                   0.009601
# 3                           -0.003095                  -0.006682
# 4                            0.013559                   0.020097
# ..                                ...                        ...
# 151                          0.000574                  -0.001742
# 152                         -0.006687                  -0.007531
# 153                          0.005451                   0.002315
# 154                         -0.005741                  -0.008696
# 155                         -0.000800                   0.008986
#
#      lit_content_density  Semantic Paraphasias  Impoverished Vocabulary  \
# 0              -0.008090             -0.020685                -0.042509
# 1               0.007416              0.062711                 0.064664
# 2               0.000367              0.063777                 0.072724
# 3              -0.007194              0.080680                 0.098618
# 4              -0.004284             -0.020047                -0.045193
# ..                   ...                   ...                      ...
# 151             0.006436              0.060342                 0.048075
# 152            -0.003530             -0.036314                -0.050602
# 153            -0.004889             -0.031739                -0.052177
# 154            -0.002146             -0.030933                 0.042881
# 155             0.002817             -0.027529                -0.057466
#
#      Discourse Impairment  Word-Finding Difficulties (Anomia)  \
# 0               -0.024756                           -0.023399
# 1                0.034070                            0.053707
# 2                0.046853                            0.057238
# 3                0.041127                            0.060625
# 4               -0.019698                           -0.022114
# ..                    ...                                 ...
# 151              0.025201                            0.046515
# 152             -0.022183                           -0.028914
# 153             -0.015764                           -0.030011
# 154             -0.016491                           -0.024758
# 155             -0.014219                           -0.024543
#
#      Syntactic Simplification
# 0                   -0.026581
# 1                    0.043466
# 2                    0.044119
# 3                    0.052542
# 4                   -0.025834
# ..                        ...
# 151                  0.023527
# 152                 -0.022496
# 153                 -0.021594
# 154                 -0.020658
# 155                 -0.016630
#
# [156 rows x 45 columns]

# %%
mean_abs_shap = shap_values.abs().mean(axis=0).sort_values(ascending=False).reset_index()
mean_abs_shap.columns = ('Feature name', 'Mean absolute\\\\&SHAP value')
mean_abs_shap
# Out:
#                                     Feature name  Mean absolute\\&SHAP value
# 0                        Impoverished Vocabulary                    0.054227
# 1             Word-Finding Difficulties (Anomia)                    0.039491
# 2                           Semantic Paraphasias                    0.037741
# 3                            lit_avg_word_length                    0.028548
# 4                       Syntactic Simplification                    0.027661
# 5                           Discourse Impairment                    0.026865
# 6                               lit_adverb_ratio                    0.026495
# 7                             lit_flesch_kincaid                    0.021346
# 8                                  lit_PRP_ratio                    0.019452
# 9                             lit_n_unique_words                    0.017239
# 10                               lit_NP -> DT_NN                    0.017199
# 11                    lit_personal_pronoun_ratio                    0.016504
# 12                         lit_honores_statistic                    0.014229
# 13                                     lit_mattr                    0.013920
# 14                        lit_pronoun_noun_ratio                    0.013913
# 15                                lit_noun_ratio                    0.012608
# 16                                   lit_n_words                    0.011988
# 17                             lit_pronoun_ratio                    0.010247
# 18                          lit_determiner_ratio                    0.008812
# 19                                  lit_VP_ratio                    0.008743
# 20          lit_verb_third_person_singular_ratio                    0.008056
# 21             lit_verb_present_participle_ratio                    0.007725
# 22           lit_avg_distance_between_utterances                    0.007394
# 23                              lit_VP -> VBG_PP                    0.007246
# 24                         lit_preposition_ratio                    0.006705
# 25                     lit_propositional_density                    0.006632
# 26                             lit_brunets_index                    0.006614
# 27                           lit_content_density                    0.006543
# 28              lit_prop_utterance_dist_below_05                    0.006144
# 29                                  lit_PP_ratio                    0.005753
# 30                                lit_verb_ratio                    0.005522
# 31                                  lit_NP_ratio                    0.004271
# 32                       lit_avg_sentence_length                    0.003468
# 33                                lit_ADVP -> RB                    0.003240
# 34                   lit_words_not_in_dict_ratio                    0.003174
# 35                                 lit_VP -> VBG                    0.003145
# 36                         lit_avg_n_words_in_NP                    0.002931
# 37                           lit_verb_noun_ratio                    0.002621
# 38                          lit_verb_modal_ratio                    0.002104
# 39                                       lit_ttr                    0.002093
# 40                                 lit_NP -> PRP                    0.001401
# 41                                lit_INTJ -> UH                    0.001178
# 42  lit_subordinate_coordinate_conjunction_ratio                    0.001164
# 43                              lit_VP -> VBD_NP                    0.000976
# 44                              lit_ROOT -> FRAG                    0.000713

# %%
mean_abs_shap_latex = mean_abs_shap.copy()
mean_abs_shap_latex['Feature name'] = [i.replace("lit_", "").replace("_", "\_") for i in mean_abs_shap_latex['Feature name']]
mean_abs_shap_latex.iloc[:,1] = mean_abs_shap_latex.iloc[:,1].apply(lambda x: f"{x:.3f}")
print(mean_abs_shap_latex.iloc[:10].to_latex(index=False))
# Out:
# \begin{tabular}{ll}
# \toprule
# Feature name & Mean absolute\\&SHAP value \\
# \midrule
# Impoverished Vocabulary & 0.054 \\
# Word-Finding Difficulties (Anomia) & 0.039 \\
# Semantic Paraphasias & 0.038 \\
# avg\_word\_length & 0.029 \\
# Syntactic Simplification & 0.028 \\
# Discourse Impairment & 0.027 \\
# adverb\_ratio & 0.026 \\
# flesch\_kincaid & 0.021 \\
# PRP\_ratio & 0.019 \\
# n\_unique\_words & 0.017 \\
# \bottomrule
# \end{tabular}
