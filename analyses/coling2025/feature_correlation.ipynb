# %%
# Results for Appendix B (feature correlation)

# %%
# make imports work
import sys
sys.path.insert(0, "/Users/JonathanHeitz/git/dementia/src/")

import matplotlib.pyplot as plt
import json
import numpy as np
import pandas as pd
import re, glob

# %%
# Results based on config /configs/gpt-paper/linguistic_features_different_sets/cross_validation/manual/linguistic_features_gpt_v6_7steps_literature.yaml
correlation = json.load(open("/Volumes/methlab/Students/Jonathan/results/runs/2024_kw34/20240821_0753_5ff6_feature_sets_cv/20240821_0816_manual_linguistic_features_gpt_v6_7steps_literature_slnu/feature_correlation.txt"))

# %%
df = pd.DataFrame(correlation)
df
# Out:
#                                               lit_pronoun_noun_ratio  \
# lit_pronoun_noun_ratio                                      1.000000
# lit_verb_noun_ratio                                         0.859883
# lit_subordinate_coordinate_conjunction_ratio                0.022604
# lit_adverb_ratio                                            0.483039
# lit_noun_ratio                                             -0.820536
# lit_verb_ratio                                              0.239760
# lit_pronoun_ratio                                           0.887073
# lit_personal_pronoun_ratio                                  0.742365
# lit_determiner_ratio                                       -0.606754
# lit_preposition_ratio                                      -0.330500
# lit_verb_present_participle_ratio                          -0.281122
# lit_verb_modal_ratio                                        0.240850
# lit_verb_third_person_singular_ratio                        0.057221
# lit_NP -> PRP                                               0.453423
# lit_ADVP -> RB                                              0.376268
# lit_NP -> DT_NN                                            -0.158771
# lit_ROOT -> FRAG                                            0.033992
# lit_VP -> VBG                                               0.073721
# lit_VP -> VBG_PP                                           -0.209504
# lit_VP -> VBD_NP                                            0.143381
# lit_INTJ -> UH                                              0.296681
# lit_NP_ratio                                               -0.072668
# lit_PRP_ratio                                               0.714330
# lit_PP_ratio                                               -0.381946
# lit_VP_ratio                                                0.141702
# lit_avg_n_words_in_NP                                      -0.295700
# lit_n_words                                                 0.158939
# lit_n_unique_words                                          0.099970
# lit_avg_word_length                                        -0.330728
# lit_avg_sentence_length                                     0.024998
# lit_words_not_in_dict_ratio                                 0.009746
# lit_brunets_index                                           0.185207
# lit_honores_statistic                                      -0.188763
# lit_ttr                                                    -0.169264
# lit_mattr                                                   0.123154
# lit_flesch_kincaid                                         -0.165676
# lit_avg_distance_between_utterances                         0.036832
# lit_prop_utterance_dist_below_05                           -0.028878
# lit_propositional_density                                   0.185713
# lit_content_density                                        -0.530017
# Semantic Paraphasias                                        0.241016
# Impoverished Vocabulary                                     0.452605
# Discourse Impairment                                        0.417032
# Word-Finding Difficulties (Anomia)                          0.474119
# Syntactic Simplification                                    0.296077
#
#                                               lit_verb_noun_ratio  \
# lit_pronoun_noun_ratio                                   0.859883
# lit_verb_noun_ratio                                      1.000000
# lit_subordinate_coordinate_conjunction_ratio             0.027345
# lit_adverb_ratio                                         0.461396
# lit_noun_ratio                                          -0.833887
# lit_verb_ratio                                           0.606369
# lit_pronoun_ratio                                        0.696421
# lit_personal_pronoun_ratio                               0.637180
# lit_determiner_ratio                                    -0.535980
# lit_preposition_ratio                                   -0.345939
# lit_verb_present_participle_ratio                        0.023012
# lit_verb_modal_ratio                                     0.188222
# lit_verb_third_person_singular_ratio                     0.169093
# lit_NP -> PRP                                            0.309005
# lit_ADVP -> RB                                           0.273899
# lit_NP -> DT_NN                                         -0.230617
# lit_ROOT -> FRAG                                        -0.098430
# lit_VP -> VBG                                            0.129887
# lit_VP -> VBG_PP                                        -0.135406
# lit_VP -> VBD_NP                                         0.099438
# lit_INTJ -> UH                                           0.137465
# lit_NP_ratio                                            -0.271222
# lit_PRP_ratio                                            0.600467
# lit_PP_ratio                                            -0.430851
# lit_VP_ratio                                             0.455039
# lit_avg_n_words_in_NP                                   -0.357208
# lit_n_words                                              0.017336
# lit_n_unique_words                                      -0.010287
# lit_avg_word_length                                     -0.172106
# lit_avg_sentence_length                                  0.026784
# lit_words_not_in_dict_ratio                             -0.091565
# lit_brunets_index                                        0.040511
# lit_honores_statistic                                   -0.092015
# lit_ttr                                                 -0.030980
# lit_mattr                                                0.042361
# lit_flesch_kincaid                                      -0.081259
# lit_avg_distance_between_utterances                      0.066034
# lit_prop_utterance_dist_below_05                         0.008910
# lit_propositional_density                                0.329552
# lit_content_density                                     -0.392787
# Semantic Paraphasias                                     0.077277
# Impoverished Vocabulary                                  0.286802
# Discourse Impairment                                     0.266431
# Word-Finding Difficulties (Anomia)                       0.273096
# Syntactic Simplification                                 0.160981
#
#                                               lit_subordinate_coordinate_conjunction_ratio  \
# lit_pronoun_noun_ratio                                                            0.022604
# lit_verb_noun_ratio                                                               0.027345
# lit_subordinate_coordinate_conjunction_ratio                                      1.000000
# lit_adverb_ratio                                                                 -0.019497
# lit_noun_ratio                                                                   -0.019047
# lit_verb_ratio                                                                    0.142234
# lit_pronoun_ratio                                                                 0.096689
# lit_personal_pronoun_ratio                                                        0.038108
# lit_determiner_ratio                                                             -0.015482
# lit_preposition_ratio                                                             0.269700
# lit_verb_present_participle_ratio                                                -0.043616
# lit_verb_modal_ratio                                                              0.034125
# lit_verb_third_person_singular_ratio                                              0.178490
# lit_NP -> PRP                                                                     0.222606
# lit_ADVP -> RB                                                                    0.123449
# lit_NP -> DT_NN                                                                   0.206031
# lit_ROOT -> FRAG                                                                 -0.054756
# lit_VP -> VBG                                                                     0.304649
# lit_VP -> VBG_PP                                                                  0.050422
# lit_VP -> VBD_NP                                                                 -0.022835
# lit_INTJ -> UH                                                                    0.138308
# lit_NP_ratio                                                                     -0.031558
# lit_PRP_ratio                                                                     0.035119
# lit_PP_ratio                                                                      0.043956
# lit_VP_ratio                                                                      0.219234
# lit_avg_n_words_in_NP                                                             0.012537
# lit_n_words                                                                       0.277599
# lit_n_unique_words                                                                0.330891
# lit_avg_word_length                                                               0.122146
# lit_avg_sentence_length                                                           0.299571
# lit_words_not_in_dict_ratio                                                      -0.063825
# lit_brunets_index                                                                 0.188733
# lit_honores_statistic                                                            -0.097465
# lit_ttr                                                                          -0.113074
# lit_mattr                                                                         0.323578
# lit_flesch_kincaid                                                                0.253994
# lit_avg_distance_between_utterances                                              -0.199466
# lit_prop_utterance_dist_below_05                                                  0.013022
# lit_propositional_density                                                         0.187275
# lit_content_density                                                               0.114983
# Semantic Paraphasias                                                             -0.094871
# Impoverished Vocabulary                                                          -0.141415
# Discourse Impairment                                                             -0.080131
# Word-Finding Difficulties (Anomia)                                               -0.073945
# Syntactic Simplification                                                         -0.176886
#
#                                               lit_adverb_ratio  \
# lit_pronoun_noun_ratio                                0.483039
# lit_verb_noun_ratio                                   0.461396
# lit_subordinate_coordinate_conjunction_ratio         -0.019497
# lit_adverb_ratio                                      1.000000
# lit_noun_ratio                                       -0.570681
# lit_verb_ratio                                        0.047781
# lit_pronoun_ratio                                     0.386237
# lit_personal_pronoun_ratio                            0.411207
# lit_determiner_ratio                                 -0.321688
# lit_preposition_ratio                                -0.298829
# lit_verb_present_participle_ratio                    -0.285495
# lit_verb_modal_ratio                                  0.186438
# lit_verb_third_person_singular_ratio                  0.020746
# lit_NP -> PRP                                         0.256849
# lit_ADVP -> RB                                        0.604947
# lit_NP -> DT_NN                                      -0.110697
# lit_ROOT -> FRAG                                      0.060518
# lit_VP -> VBG                                        -0.072529
# lit_VP -> VBG_PP                                     -0.184057
# lit_VP -> VBD_NP                                      0.161407
# lit_INTJ -> UH                                        0.101164
# lit_NP_ratio                                         -0.149965
# lit_PRP_ratio                                         0.396423
# lit_PP_ratio                                         -0.353299
# lit_VP_ratio                                          0.085943
# lit_avg_n_words_in_NP                                -0.076172
# lit_n_words                                           0.099193
# lit_n_unique_words                                    0.083694
# lit_avg_word_length                                  -0.202350
# lit_avg_sentence_length                               0.044629
# lit_words_not_in_dict_ratio                           0.026966
# lit_brunets_index                                     0.110075
# lit_honores_statistic                                -0.201114
# lit_ttr                                              -0.132021
# lit_mattr                                             0.096630
# lit_flesch_kincaid                                   -0.143762
# lit_avg_distance_between_utterances                   0.135035
# lit_prop_utterance_dist_below_05                     -0.059131
# lit_propositional_density                             0.470591
# lit_content_density                                   0.004521
# Semantic Paraphasias                                  0.115349
# Impoverished Vocabulary                               0.325242
# Discourse Impairment                                  0.272793
# Word-Finding Difficulties (Anomia)                    0.297309
# Syntactic Simplification                              0.244383
#
#                                               lit_noun_ratio  lit_verb_ratio  \
# lit_pronoun_noun_ratio                             -0.820536        0.239760
# lit_verb_noun_ratio                                -0.833887        0.606369
# lit_subordinate_coordinate_conjunction_ratio       -0.019047        0.142234
# lit_adverb_ratio                                   -0.570681        0.047781
# lit_noun_ratio                                      1.000000       -0.312925
# lit_verb_ratio                                     -0.312925        1.000000
# lit_pronoun_ratio                                  -0.760046        0.255627
# lit_personal_pronoun_ratio                         -0.725491        0.253528
# lit_determiner_ratio                                0.512056       -0.214342
# lit_preposition_ratio                               0.341067       -0.100479
# lit_verb_present_participle_ratio                   0.182073        0.515842
# lit_verb_modal_ratio                               -0.290418       -0.069599
# lit_verb_third_person_singular_ratio               -0.097927        0.240819
# lit_NP -> PRP                                      -0.430964        0.078209
# lit_ADVP -> RB                                     -0.425284       -0.045030
# lit_NP -> DT_NN                                     0.196034       -0.135431
# lit_ROOT -> FRAG                                   -0.059794       -0.240563
# lit_VP -> VBG                                      -0.095627        0.201900
# lit_VP -> VBG_PP                                    0.208879        0.169464
# lit_VP -> VBD_NP                                   -0.193565        0.007390
# lit_INTJ -> UH                                     -0.267856       -0.098756
# lit_NP_ratio                                        0.353238       -0.257092
# lit_PRP_ratio                                      -0.705466        0.217198
# lit_PP_ratio                                        0.437924       -0.219060
# lit_VP_ratio                                       -0.345943        0.670745
# lit_avg_n_words_in_NP                               0.367607       -0.280490
# lit_n_words                                        -0.123711       -0.084036
# lit_n_unique_words                                 -0.088532       -0.050390
# lit_avg_word_length                                 0.367710        0.248044
# lit_avg_sentence_length                            -0.096769        0.034388
# lit_words_not_in_dict_ratio                        -0.041732       -0.271770
# lit_brunets_index                                  -0.155202       -0.103195
# lit_honores_statistic                               0.196982        0.069174
# lit_ttr                                             0.142972        0.142259
# lit_mattr                                          -0.148647        0.037723
# lit_flesch_kincaid                                  0.105590        0.111812
# lit_avg_distance_between_utterances                -0.044210       -0.072871
# lit_prop_utterance_dist_below_05                    0.031484        0.125727
# lit_propositional_density                          -0.345581        0.341482
# lit_content_density                                 0.629086        0.152312
# Semantic Paraphasias                               -0.184423       -0.254807
# Impoverished Vocabulary                            -0.379807       -0.144562
# Discourse Impairment                               -0.418440       -0.106413
# Word-Finding Difficulties (Anomia)                 -0.415705       -0.189835
# Syntactic Simplification                           -0.294149       -0.211797
#
#                                               lit_pronoun_ratio  \
# lit_pronoun_noun_ratio                                 0.887073
# lit_verb_noun_ratio                                    0.696421
# lit_subordinate_coordinate_conjunction_ratio           0.096689
# lit_adverb_ratio                                       0.386237
# lit_noun_ratio                                        -0.760046
# lit_verb_ratio                                         0.255627
# lit_pronoun_ratio                                      1.000000
# lit_personal_pronoun_ratio                             0.826338
# lit_determiner_ratio                                  -0.580546
# lit_preposition_ratio                                 -0.256207
# lit_verb_present_participle_ratio                     -0.312242
# lit_verb_modal_ratio                                   0.217129
# lit_verb_third_person_singular_ratio                   0.047418
# lit_NP -> PRP                                          0.575593
# lit_ADVP -> RB                                         0.353774
# lit_NP -> DT_NN                                       -0.059279
# lit_ROOT -> FRAG                                       0.059622
# lit_VP -> VBG                                          0.081504
# lit_VP -> VBG_PP                                      -0.097780
# lit_VP -> VBD_NP                                       0.213654
# lit_INTJ -> UH                                         0.267953
# lit_NP_ratio                                           0.043677
# lit_PRP_ratio                                          0.807221
# lit_PP_ratio                                          -0.327307
# lit_VP_ratio                                           0.131620
# lit_avg_n_words_in_NP                                 -0.251004
# lit_n_words                                            0.279424
# lit_n_unique_words                                     0.252552
# lit_avg_word_length                                   -0.298172
# lit_avg_sentence_length                                0.101261
# lit_words_not_in_dict_ratio                           -0.031677
# lit_brunets_index                                      0.284050
# lit_honores_statistic                                 -0.238333
# lit_ttr                                               -0.234176
# lit_mattr                                              0.301196
# lit_flesch_kincaid                                    -0.113370
# lit_avg_distance_between_utterances                   -0.045822
# lit_prop_utterance_dist_below_05                      -0.002841
# lit_propositional_density                              0.196054
# lit_content_density                                   -0.482698
# Semantic Paraphasias                                   0.189785
# Impoverished Vocabulary                                0.359861
# Discourse Impairment                                   0.398334
# Word-Finding Difficulties (Anomia)                     0.420311
# Syntactic Simplification                               0.236949
#
#                                               lit_personal_pronoun_ratio  \
# lit_pronoun_noun_ratio                                          0.742365
# lit_verb_noun_ratio                                             0.637180
# lit_subordinate_coordinate_conjunction_ratio                    0.038108
# lit_adverb_ratio                                                0.411207
# lit_noun_ratio                                                 -0.725491
# lit_verb_ratio                                                  0.253528
# lit_pronoun_ratio                                               0.826338
# lit_personal_pronoun_ratio                                      1.000000
# lit_determiner_ratio                                           -0.523406
# lit_preposition_ratio                                          -0.223076
# lit_verb_present_participle_ratio                              -0.247216
# lit_verb_modal_ratio                                            0.271693
# lit_verb_third_person_singular_ratio                           -0.017055
# lit_NP -> PRP                                                   0.641250
# lit_ADVP -> RB                                                  0.337532
# lit_NP -> DT_NN                                                -0.113154
# lit_ROOT -> FRAG                                               -0.009506
# lit_VP -> VBG                                                  -0.026178
# lit_VP -> VBG_PP                                               -0.132779
# lit_VP -> VBD_NP                                                0.193697
# lit_INTJ -> UH                                                  0.159587
# lit_NP_ratio                                                   -0.009791
# lit_PRP_ratio                                                   0.996760
# lit_PP_ratio                                                   -0.312734
# lit_VP_ratio                                                    0.181439
# lit_avg_n_words_in_NP                                          -0.284588
# lit_n_words                                                     0.219597
# lit_n_unique_words                                              0.193775
# lit_avg_word_length                                            -0.343861
# lit_avg_sentence_length                                         0.160721
# lit_words_not_in_dict_ratio                                    -0.061012
# lit_brunets_index                                               0.220905
# lit_honores_statistic                                          -0.244194
# lit_ttr                                                        -0.218070
# lit_mattr                                                       0.189965
# lit_flesch_kincaid                                             -0.078787
# lit_avg_distance_between_utterances                             0.074387
# lit_prop_utterance_dist_below_05                               -0.059530
# lit_propositional_density                                       0.298298
# lit_content_density                                            -0.441841
# Semantic Paraphasias                                            0.187150
# Impoverished Vocabulary                                         0.326934
# Discourse Impairment                                            0.361555
# Word-Finding Difficulties (Anomia)                              0.372108
# Syntactic Simplification                                        0.265577
#
#                                               lit_determiner_ratio  \
# lit_pronoun_noun_ratio                                   -0.606754
# lit_verb_noun_ratio                                      -0.535980
# lit_subordinate_coordinate_conjunction_ratio             -0.015482
# lit_adverb_ratio                                         -0.321688
# lit_noun_ratio                                            0.512056
# lit_verb_ratio                                           -0.214342
# lit_pronoun_ratio                                        -0.580546
# lit_personal_pronoun_ratio                               -0.523406
# lit_determiner_ratio                                      1.000000
# lit_preposition_ratio                                     0.355862
# lit_verb_present_participle_ratio                         0.060023
# lit_verb_modal_ratio                                     -0.152272
# lit_verb_third_person_singular_ratio                      0.145168
# lit_NP -> PRP                                            -0.271965
# lit_ADVP -> RB                                           -0.204430
# lit_NP -> DT_NN                                           0.372719
# lit_ROOT -> FRAG                                         -0.129125
# lit_VP -> VBG                                            -0.001443
# lit_VP -> VBG_PP                                          0.183732
# lit_VP -> VBD_NP                                         -0.023056
# lit_INTJ -> UH                                           -0.319505
# lit_NP_ratio                                              0.221914
# lit_PRP_ratio                                            -0.504805
# lit_PP_ratio                                              0.402943
# lit_VP_ratio                                             -0.026457
# lit_avg_n_words_in_NP                                     0.326781
# lit_n_words                                              -0.019426
# lit_n_unique_words                                       -0.004875
# lit_avg_word_length                                       0.269014
# lit_avg_sentence_length                                   0.225563
# lit_words_not_in_dict_ratio                              -0.170539
# lit_brunets_index                                        -0.023023
# lit_honores_statistic                                     0.046482
# lit_ttr                                                   0.014438
# lit_mattr                                                 0.021954
# lit_flesch_kincaid                                        0.271774
# lit_avg_distance_between_utterances                      -0.229903
# lit_prop_utterance_dist_below_05                          0.134843
# lit_propositional_density                                -0.043337
# lit_content_density                                       0.268128
# Semantic Paraphasias                                     -0.315414
# Impoverished Vocabulary                                  -0.378647
# Discourse Impairment                                     -0.406191
# Word-Finding Difficulties (Anomia)                       -0.403669
# Syntactic Simplification                                 -0.376780
#
#                                               lit_preposition_ratio  ...  \
# lit_pronoun_noun_ratio                                    -0.330500  ...
# lit_verb_noun_ratio                                       -0.345939  ...
# lit_subordinate_coordinate_conjunction_ratio               0.269700  ...
# lit_adverb_ratio                                          -0.298829  ...
# lit_noun_ratio                                             0.341067  ...
# lit_verb_ratio                                            -0.100479  ...
# lit_pronoun_ratio                                         -0.256207  ...
# lit_personal_pronoun_ratio                                -0.223076  ...
# lit_determiner_ratio                                       0.355862  ...
# lit_preposition_ratio                                      1.000000  ...
# lit_verb_present_participle_ratio                          0.066978  ...
# lit_verb_modal_ratio                                      -0.176261  ...
# lit_verb_third_person_singular_ratio                       0.045266  ...
# lit_NP -> PRP                                              0.081831  ...
# lit_ADVP -> RB                                            -0.024416  ...
# lit_NP -> DT_NN                                            0.449627  ...
# lit_ROOT -> FRAG                                          -0.075854  ...
# lit_VP -> VBG                                             -0.077565  ...
# lit_VP -> VBG_PP                                           0.397390  ...
# lit_VP -> VBD_NP                                          -0.087665  ...
# lit_INTJ -> UH                                            -0.101127  ...
# lit_NP_ratio                                               0.173227  ...
# lit_PRP_ratio                                             -0.214638  ...
# lit_PP_ratio                                               0.916319  ...
# lit_VP_ratio                                              -0.099121  ...
# lit_avg_n_words_in_NP                                      0.177818  ...
# lit_n_words                                                0.256725  ...
# lit_n_unique_words                                         0.331281  ...
# lit_avg_word_length                                        0.390750  ...
# lit_avg_sentence_length                                    0.486130  ...
# lit_words_not_in_dict_ratio                               -0.247553  ...
# lit_brunets_index                                          0.162117  ...
# lit_honores_statistic                                      0.052893  ...
# lit_ttr                                                   -0.062837  ...
# lit_mattr                                                  0.324969  ...
# lit_flesch_kincaid                                         0.561377  ...
# lit_avg_distance_between_utterances                       -0.277993  ...
# lit_prop_utterance_dist_below_05                           0.181711  ...
# lit_propositional_density                                  0.355467  ...
# lit_content_density                                        0.175314  ...
# Semantic Paraphasias                                      -0.309437  ...
# Impoverished Vocabulary                                   -0.389140  ...
# Discourse Impairment                                      -0.334517  ...
# Word-Finding Difficulties (Anomia)                        -0.303559  ...
# Syntactic Simplification                                  -0.372583  ...
#
#                                               lit_flesch_kincaid  \
# lit_pronoun_noun_ratio                                 -0.165676
# lit_verb_noun_ratio                                    -0.081259
# lit_subordinate_coordinate_conjunction_ratio            0.253994
# lit_adverb_ratio                                       -0.143762
# lit_noun_ratio                                          0.105590
# lit_verb_ratio                                          0.111812
# lit_pronoun_ratio                                      -0.113370
# lit_personal_pronoun_ratio                             -0.078787
# lit_determiner_ratio                                    0.271774
# lit_preposition_ratio                                   0.561377
# lit_verb_present_participle_ratio                       0.098419
# lit_verb_modal_ratio                                   -0.005317
# lit_verb_third_person_singular_ratio                    0.059493
# lit_NP -> PRP                                           0.175733
# lit_ADVP -> RB                                          0.094335
# lit_NP -> DT_NN                                         0.366554
# lit_ROOT -> FRAG                                       -0.133222
# lit_VP -> VBG                                           0.143486
# lit_VP -> VBG_PP                                        0.248926
# lit_VP -> VBD_NP                                       -0.049408
# lit_INTJ -> UH                                         -0.159818
# lit_NP_ratio                                            0.080922
# lit_PRP_ratio                                          -0.076924
# lit_PP_ratio                                            0.430936
# lit_VP_ratio                                            0.223776
# lit_avg_n_words_in_NP                                   0.302413
# lit_n_words                                             0.289091
# lit_n_unique_words                                      0.387532
# lit_avg_word_length                                     0.589416
# lit_avg_sentence_length                                 0.863566
# lit_words_not_in_dict_ratio                            -0.191421
# lit_brunets_index                                       0.149471
# lit_honores_statistic                                   0.063897
# lit_ttr                                                -0.026173
# lit_mattr                                               0.392089
# lit_flesch_kincaid                                      1.000000
# lit_avg_distance_between_utterances                    -0.419469
# lit_prop_utterance_dist_below_05                        0.304756
# lit_propositional_density                               0.464238
# lit_content_density                                     0.195961
# Semantic Paraphasias                                   -0.272867
# Impoverished Vocabulary                                -0.411763
# Discourse Impairment                                   -0.348726
# Word-Finding Difficulties (Anomia)                     -0.227103
# Syntactic Simplification                               -0.402084
#
#                                               lit_avg_distance_between_utterances  \
# lit_pronoun_noun_ratio                                                   0.036832
# lit_verb_noun_ratio                                                      0.066034
# lit_subordinate_coordinate_conjunction_ratio                            -0.199466
# lit_adverb_ratio                                                         0.135035
# lit_noun_ratio                                                          -0.044210
# lit_verb_ratio                                                          -0.072871
# lit_pronoun_ratio                                                       -0.045822
# lit_personal_pronoun_ratio                                               0.074387
# lit_determiner_ratio                                                    -0.229903
# lit_preposition_ratio                                                   -0.277993
# lit_verb_present_participle_ratio                                        0.039038
# lit_verb_modal_ratio                                                     0.013325
# lit_verb_third_person_singular_ratio                                    -0.024000
# lit_NP -> PRP                                                           -0.165708
# lit_ADVP -> RB                                                          -0.099677
# lit_NP -> DT_NN                                                         -0.292025
# lit_ROOT -> FRAG                                                         0.000628
# lit_VP -> VBG                                                           -0.188061
# lit_VP -> VBG_PP                                                        -0.098905
# lit_VP -> VBD_NP                                                        -0.079374
# lit_INTJ -> UH                                                          -0.118053
# lit_NP_ratio                                                            -0.003993
# lit_PRP_ratio                                                            0.076403
# lit_PP_ratio                                                            -0.232991
# lit_VP_ratio                                                            -0.156131
# lit_avg_n_words_in_NP                                                   -0.183493
# lit_n_words                                                             -0.253479
# lit_n_unique_words                                                      -0.342159
# lit_avg_word_length                                                     -0.288294
# lit_avg_sentence_length                                                 -0.421017
# lit_words_not_in_dict_ratio                                              0.198677
# lit_brunets_index                                                       -0.111345
# lit_honores_statistic                                                   -0.138167
# lit_ttr                                                                 -0.067141
# lit_mattr                                                               -0.424237
# lit_flesch_kincaid                                                      -0.419469
# lit_avg_distance_between_utterances                                      1.000000
# lit_prop_utterance_dist_below_05                                        -0.624926
# lit_propositional_density                                               -0.117586
# lit_content_density                                                     -0.028678
# Semantic Paraphasias                                                     0.319226
# Impoverished Vocabulary                                                  0.306477
# Discourse Impairment                                                     0.282279
# Word-Finding Difficulties (Anomia)                                       0.155107
# Syntactic Simplification                                                 0.337222
#
#                                               lit_prop_utterance_dist_below_05  \
# lit_pronoun_noun_ratio                                               -0.028878
# lit_verb_noun_ratio                                                   0.008910
# lit_subordinate_coordinate_conjunction_ratio                          0.013022
# lit_adverb_ratio                                                     -0.059131
# lit_noun_ratio                                                        0.031484
# lit_verb_ratio                                                        0.125727
# lit_pronoun_ratio                                                    -0.002841
# lit_personal_pronoun_ratio                                           -0.059530
# lit_determiner_ratio                                                  0.134843
# lit_preposition_ratio                                                 0.181711
# lit_verb_present_participle_ratio                                     0.039301
# lit_verb_modal_ratio                                                 -0.160744
# lit_verb_third_person_singular_ratio                                  0.010387
# lit_NP -> PRP                                                         0.085981
# lit_ADVP -> RB                                                        0.089190
# lit_NP -> DT_NN                                                       0.198430
# lit_ROOT -> FRAG                                                     -0.022530
# lit_VP -> VBG                                                         0.055199
# lit_VP -> VBG_PP                                                      0.117277
# lit_VP -> VBD_NP                                                      0.023416
# lit_INTJ -> UH                                                        0.008011
# lit_NP_ratio                                                         -0.085237
# lit_PRP_ratio                                                        -0.061205
# lit_PP_ratio                                                          0.230429
# lit_VP_ratio                                                          0.111627
# lit_avg_n_words_in_NP                                                 0.052067
# lit_n_words                                                           0.151780
# lit_n_unique_words                                                    0.233216
# lit_avg_word_length                                                   0.214422
# lit_avg_sentence_length                                               0.306006
# lit_words_not_in_dict_ratio                                          -0.147932
# lit_brunets_index                                                     0.044598
# lit_honores_statistic                                                 0.201959
# lit_ttr                                                               0.080366
# lit_mattr                                                             0.299701
# lit_flesch_kincaid                                                    0.304756
# lit_avg_distance_between_utterances                                  -0.624926
# lit_prop_utterance_dist_below_05                                      1.000000
# lit_propositional_density                                             0.156710
# lit_content_density                                                   0.074803
# Semantic Paraphasias                                                 -0.318838
# Impoverished Vocabulary                                              -0.292875
# Discourse Impairment                                                 -0.281945
# Word-Finding Difficulties (Anomia)                                   -0.195804
# Syntactic Simplification                                             -0.255745
#
#                                               lit_propositional_density  \
# lit_pronoun_noun_ratio                                         0.185713
# lit_verb_noun_ratio                                            0.329552
# lit_subordinate_coordinate_conjunction_ratio                   0.187275
# lit_adverb_ratio                                               0.470591
# lit_noun_ratio                                                -0.345581
# lit_verb_ratio                                                 0.341482
# lit_pronoun_ratio                                              0.196054
# lit_personal_pronoun_ratio                                     0.298298
# lit_determiner_ratio                                          -0.043337
# lit_preposition_ratio                                          0.355467
# lit_verb_present_participle_ratio                              0.036167
# lit_verb_modal_ratio                                          -0.018395
# lit_verb_third_person_singular_ratio                           0.067507
# lit_NP -> PRP                                                  0.268487
# lit_ADVP -> RB                                                 0.351880
# lit_NP -> DT_NN                                                0.116523
# lit_ROOT -> FRAG                                              -0.038648
# lit_VP -> VBG                                                 -0.020686
# lit_VP -> VBG_PP                                               0.134502
# lit_VP -> VBD_NP                                               0.073028
# lit_INTJ -> UH                                                -0.170056
# lit_NP_ratio                                                  -0.113241
# lit_PRP_ratio                                                  0.293430
# lit_PP_ratio                                                   0.192775
# lit_VP_ratio                                                   0.298854
# lit_avg_n_words_in_NP                                          0.065981
# lit_n_words                                                    0.196580
# lit_n_unique_words                                             0.266479
# lit_avg_word_length                                            0.361833
# lit_avg_sentence_length                                        0.513131
# lit_words_not_in_dict_ratio                                   -0.205467
# lit_brunets_index                                              0.155274
# lit_honores_statistic                                         -0.080245
# lit_ttr                                                       -0.082858
# lit_mattr                                                      0.369467
# lit_flesch_kincaid                                             0.464238
# lit_avg_distance_between_utterances                           -0.117586
# lit_prop_utterance_dist_below_05                               0.156710
# lit_propositional_density                                      1.000000
# lit_content_density                                            0.223975
# Semantic Paraphasias                                          -0.225486
# Impoverished Vocabulary                                       -0.151519
# Discourse Impairment                                          -0.122692
# Word-Finding Difficulties (Anomia)                            -0.104293
# Syntactic Simplification                                      -0.222030
#
#                                               lit_content_density  \
# lit_pronoun_noun_ratio                                  -0.530017
# lit_verb_noun_ratio                                     -0.392787
# lit_subordinate_coordinate_conjunction_ratio             0.114983
# lit_adverb_ratio                                         0.004521
# lit_noun_ratio                                           0.629086
# lit_verb_ratio                                           0.152312
# lit_pronoun_ratio                                       -0.482698
# lit_personal_pronoun_ratio                              -0.441841
# lit_determiner_ratio                                     0.268128
# lit_preposition_ratio                                    0.175314
# lit_verb_present_participle_ratio                        0.231036
# lit_verb_modal_ratio                                    -0.294759
# lit_verb_third_person_singular_ratio                    -0.016051
# lit_NP -> PRP                                           -0.277951
# lit_ADVP -> RB                                          -0.136764
# lit_NP -> DT_NN                                          0.061477
# lit_ROOT -> FRAG                                        -0.138223
# lit_VP -> VBG                                           -0.047459
# lit_VP -> VBG_PP                                         0.209114
# lit_VP -> VBD_NP                                        -0.108600
# lit_INTJ -> UH                                          -0.370239
# lit_NP_ratio                                             0.200507
# lit_PRP_ratio                                           -0.443144
# lit_PP_ratio                                             0.173246
# lit_VP_ratio                                            -0.011965
# lit_avg_n_words_in_NP                                    0.311670
# lit_n_words                                             -0.083347
# lit_n_unique_words                                      -0.006889
# lit_avg_word_length                                      0.532384
# lit_avg_sentence_length                                  0.007683
# lit_words_not_in_dict_ratio                             -0.169845
# lit_brunets_index                                       -0.133745
# lit_honores_statistic                                    0.107055
# lit_ttr                                                  0.145613
# lit_mattr                                                0.012802
# lit_flesch_kincaid                                       0.195961
# lit_avg_distance_between_utterances                     -0.028678
# lit_prop_utterance_dist_below_05                         0.074803
# lit_propositional_density                                0.223975
# lit_content_density                                      1.000000
# Semantic Paraphasias                                    -0.275432
# ...
# lit_ADVP -> RB                                            0.140467
# lit_NP -> DT_NN                                          -0.237737
# lit_ROOT -> FRAG                                          0.112450
# lit_VP -> VBG                                            -0.122090
# lit_VP -> VBG_PP                                         -0.289068
# lit_VP -> VBD_NP                                          0.153325
# lit_INTJ -> UH                                            0.170785
# lit_NP_ratio                                              0.040197
# lit_PRP_ratio                                             0.189566
# lit_PP_ratio                                             -0.315999
# lit_VP_ratio                                             -0.326093
# lit_avg_n_words_in_NP                                    -0.037438
# lit_n_words                                              -0.029816
# lit_n_unique_words                                       -0.132611
# lit_avg_word_length                                      -0.424565
# lit_avg_sentence_length                                  -0.132801
# lit_words_not_in_dict_ratio                               0.307781
# lit_brunets_index                                         0.074703
# lit_honores_statistic                                    -0.338562
# lit_ttr                                                  -0.193855
# lit_mattr                                                -0.228567
# lit_flesch_kincaid                                       -0.272867
# lit_avg_distance_between_utterances                       0.319226
# lit_prop_utterance_dist_below_05                         -0.318838
# lit_propositional_density                                -0.225486
# lit_content_density                                      -0.275432
# Semantic Paraphasias                                      1.000000
# Impoverished Vocabulary                                   0.699615
# Discourse Impairment                                      0.713714
# Word-Finding Difficulties (Anomia)                        0.720754
# Syntactic Simplification                                  0.639189
#
#                                               Impoverished Vocabulary  \
# lit_pronoun_noun_ratio                                       0.452605
# lit_verb_noun_ratio                                          0.286802
# lit_subordinate_coordinate_conjunction_ratio                -0.141415
# lit_adverb_ratio                                             0.325242
# lit_noun_ratio                                              -0.379807
# lit_verb_ratio                                              -0.144562
# lit_pronoun_ratio                                            0.359861
# lit_personal_pronoun_ratio                                   0.326934
# lit_determiner_ratio                                        -0.378647
# lit_preposition_ratio                                       -0.389140
# lit_verb_present_participle_ratio                           -0.406114
# lit_verb_modal_ratio                                         0.161597
# lit_verb_third_person_singular_ratio                        -0.301623
# lit_NP -> PRP                                                0.137171
# lit_ADVP -> RB                                               0.225475
# lit_NP -> DT_NN                                             -0.308101
# lit_ROOT -> FRAG                                             0.194348
# lit_VP -> VBG                                               -0.092583
# lit_VP -> VBG_PP                                            -0.380079
# lit_VP -> VBD_NP                                             0.259236
# lit_INTJ -> UH                                               0.255861
# lit_NP_ratio                                                 0.059164
# lit_PRP_ratio                                                0.326407
# lit_PP_ratio                                                -0.367363
# lit_VP_ratio                                                -0.365385
# lit_avg_n_words_in_NP                                       -0.062589
# lit_n_words                                                 -0.024734
# lit_n_unique_words                                          -0.165000
# lit_avg_word_length                                         -0.518173
# lit_avg_sentence_length                                     -0.242279
# lit_words_not_in_dict_ratio                                  0.162776
# lit_brunets_index                                            0.090464
# lit_honores_statistic                                       -0.346351
# lit_ttr                                                     -0.209833
# lit_mattr                                                   -0.239621
# lit_flesch_kincaid                                          -0.411763
# lit_avg_distance_between_utterances                          0.306477
# lit_prop_utterance_dist_below_05                            -0.292875
# lit_propositional_density                                   -0.151519
# lit_content_density                                         -0.310316
# Semantic Paraphasias                                         0.699615
# Impoverished Vocabulary                                      1.000000
# Discourse Impairment                                         0.818242
# Word-Finding Difficulties (Anomia)                           0.820226
# Syntactic Simplification                                     0.764612
#
#                                               Discourse Impairment  \
# lit_pronoun_noun_ratio                                    0.417032
# lit_verb_noun_ratio                                       0.266431
# lit_subordinate_coordinate_conjunction_ratio             -0.080131
# lit_adverb_ratio                                          0.272793
# lit_noun_ratio                                           -0.418440
# lit_verb_ratio                                           -0.106413
# lit_pronoun_ratio                                         0.398334
# lit_personal_pronoun_ratio                                0.361555
# lit_determiner_ratio                                     -0.406191
# lit_preposition_ratio                                    -0.334517
# lit_verb_present_participle_ratio                        -0.398603
# lit_verb_modal_ratio                                      0.221028
# lit_verb_third_person_singular_ratio                     -0.320991
# lit_NP -> PRP                                             0.256876
# lit_ADVP -> RB                                            0.257678
# lit_NP -> DT_NN                                          -0.244789
# lit_ROOT -> FRAG                                          0.231717
# lit_VP -> VBG                                            -0.071593
# lit_VP -> VBG_PP                                         -0.328119
# lit_VP -> VBD_NP                                          0.297597
# lit_INTJ -> UH                                            0.306770
# lit_NP_ratio                                             -0.023260
# lit_PRP_ratio                                             0.362166
# lit_PP_ratio                                             -0.349880
# lit_VP_ratio                                             -0.259634
# lit_avg_n_words_in_NP                                    -0.086176
# lit_n_words                                               0.089678
# lit_n_unique_words                                       -0.024220
# lit_avg_word_length                                      -0.551835
# lit_avg_sentence_length                                  -0.142032
# lit_words_not_in_dict_ratio                               0.168374
# lit_brunets_index                                         0.177720
# lit_honores_statistic                                    -0.361829
# lit_ttr                                                  -0.263848
# lit_mattr                                                -0.105504
# lit_flesch_kincaid                                       -0.348726
# lit_avg_distance_between_utterances                       0.282279
# lit_prop_utterance_dist_below_05                         -0.281945
# lit_propositional_density                                -0.122692
# lit_content_density                                      -0.358080
# Semantic Paraphasias                                      0.713714
# Impoverished Vocabulary                                   0.818242
# Discourse Impairment                                      1.000000
# Word-Finding Difficulties (Anomia)                        0.838122
# Syntactic Simplification                                  0.778236
#
#                                               Word-Finding Difficulties (Anomia)  \
# lit_pronoun_noun_ratio                                                  0.474119
# lit_verb_noun_ratio                                                     0.273096
# lit_subordinate_coordinate_conjunction_ratio                           -0.073945
# lit_adverb_ratio                                                        0.297309
# lit_noun_ratio                                                         -0.415705
# lit_verb_ratio                                                         -0.189835
# lit_pronoun_ratio                                                       0.420311
# lit_personal_pronoun_ratio                                              0.372108
# lit_determiner_ratio                                                   -0.403669
# lit_preposition_ratio                                                  -0.303559
# lit_verb_present_participle_ratio                                      -0.498958
# lit_verb_modal_ratio                                                    0.181945
# lit_verb_third_person_singular_ratio                                   -0.273555
# lit_NP -> PRP                                                           0.295070
# lit_ADVP -> RB                                                          0.319020
# lit_NP -> DT_NN                                                        -0.203468
# lit_ROOT -> FRAG                                                        0.243408
# lit_VP -> VBG                                                          -0.071134
# lit_VP -> VBG_PP                                                       -0.336542
# lit_VP -> VBD_NP                                                        0.268551
# lit_INTJ -> UH                                                          0.378928
# lit_NP_ratio                                                            0.056634
# lit_PRP_ratio                                                           0.374001
# lit_PP_ratio                                                           -0.300639
# lit_VP_ratio                                                           -0.332653
# lit_avg_n_words_in_NP                                                   0.038658
# lit_n_words                                                             0.148126
# lit_n_unique_words                                                      0.027820
# lit_avg_word_length                                                    -0.543131
# lit_avg_sentence_length                                                 0.002144
# lit_words_not_in_dict_ratio                                             0.165109
# lit_brunets_index                                                       0.253222
# lit_honores_statistic                                                  -0.379199
# lit_ttr                                                                -0.324559
# lit_mattr                                                              -0.048585
# lit_flesch_kincaid                                                     -0.227103
# lit_avg_distance_between_utterances                                     0.155107
# lit_prop_utterance_dist_below_05                                       -0.195804
# lit_propositional_density                                              -0.104293
# lit_content_density                                                    -0.377772
# Semantic Paraphasias                                                    0.720754
# Impoverished Vocabulary                                                 0.820226
# Discourse Impairment                                                    0.838122
# Word-Finding Difficulties (Anomia)                                      1.000000
# Syntactic Simplification                                                0.763160
#
#                                               Syntactic Simplification
# lit_pronoun_noun_ratio                                        0.296077
# lit_verb_noun_ratio                                           0.160981
# lit_subordinate_coordinate_conjunction_ratio                 -0.176886
# lit_adverb_ratio                                              0.244383
# lit_noun_ratio                                               -0.294149
# lit_verb_ratio                                               -0.211797
# lit_pronoun_ratio                                             0.236949
# lit_personal_pronoun_ratio                                    0.265577
# lit_determiner_ratio                                         -0.376780
# lit_preposition_ratio                                        -0.372583
# lit_verb_present_participle_ratio                            -0.367318
# lit_verb_modal_ratio                                          0.039863
# lit_verb_third_person_singular_ratio                         -0.290779
# lit_NP -> PRP                                                 0.081319
# lit_ADVP -> RB                                                0.155051
# lit_NP -> DT_NN                                              -0.334814
# lit_ROOT -> FRAG                                              0.167412
# lit_VP -> VBG                                                -0.200465
# lit_VP -> VBG_PP                                             -0.382708
# lit_VP -> VBD_NP                                              0.236706
# lit_INTJ -> UH                                                0.223063
# lit_NP_ratio                                                 -0.033963
# lit_PRP_ratio                                                 0.274999
# lit_PP_ratio                                                 -0.332860
# lit_VP_ratio                                                 -0.351842
# lit_avg_n_words_in_NP                                        -0.053245
# lit_n_words                                                  -0.061500
# lit_n_unique_words                                           -0.186557
# lit_avg_word_length                                          -0.544896
# lit_avg_sentence_length                                      -0.228967
# lit_words_not_in_dict_ratio                                   0.170894
# lit_brunets_index                                             0.029435
# lit_honores_statistic                                        -0.278919
# lit_ttr                                                      -0.157784
# lit_mattr                                                    -0.292902
# lit_flesch_kincaid                                           -0.402084
# lit_avg_distance_between_utterances                           0.337222
# lit_prop_utterance_dist_below_05                             -0.255745
# lit_propositional_density                                    -0.222030
# lit_content_density                                          -0.297406
# Semantic Paraphasias                                          0.639189
# Impoverished Vocabulary                                       0.764612
# Discourse Impairment                                          0.778236
# Word-Finding Difficulties (Anomia)                            0.763160
# Syntactic Simplification                                      1.000000
#
# [45 rows x 45 columns]

# %%
from matplotlib import rc, font_manager



rc('font',**{'family':'serif','serif':['Times']})

fig, ax = plt.subplots(1, 1,figsize=(10,10))
im = ax.imshow(df, 
           cmap="coolwarm", vmin=-1, vmax=1)
ax.set_yticks(range(len(df.index)), df.index)
ax.set_xticks(range(len(df.columns)), df.columns, rotation=45, ha='right')
#for (i, j), z in np.ndenumerate(df):
#    plt.text(j, i, '{:0.2f}'.format(z), ha='center', va='center', fontsize=5)
axins = ax.inset_axes(bounds=(0,-0.22,1,0.02)
                    #width="200%",  
                    #height="2%",
                    #loc='lower left',
                    #borderpad=-10
                   )
#plt.colorbar(orientation='horizontal',fraction=0.01, pad=0.2)
fig.colorbar(im, cax=axins, orientation="horizontal")

# %%
col_subset = df[[c for c in df.columns if 'lit_' not in c]]
row_subset = col_subset.loc[[idx for idx in col_subset.index if 'lit_' in idx]]
row_subset['sort'] = row_subset.mean(axis=1).abs()
row_subset = row_subset.sort_values(by="sort", ascending=False)
row_subset = row_subset.drop(columns=['sort'])
row_subset
# Out:
#                                               Semantic Paraphasias  \
# lit_avg_word_length                                      -0.424565
# lit_verb_present_participle_ratio                        -0.346138
# lit_pronoun_noun_ratio                                    0.241016
# lit_determiner_ratio                                     -0.315414
# lit_VP -> VBG_PP                                         -0.289068
# lit_preposition_ratio                                    -0.309437
# lit_honores_statistic                                    -0.338562
# lit_noun_ratio                                           -0.184423
# lit_PP_ratio                                             -0.315999
# lit_flesch_kincaid                                       -0.272867
# lit_VP_ratio                                             -0.326093
# lit_content_density                                      -0.275432
# lit_pronoun_ratio                                         0.189785
# lit_PRP_ratio                                             0.189566
# lit_personal_pronoun_ratio                                0.187150
# lit_verb_third_person_singular_ratio                     -0.304370
# lit_avg_distance_between_utterances                       0.319226
# lit_prop_utterance_dist_below_05                         -0.318838
# lit_INTJ -> UH                                            0.170785
# lit_NP -> DT_NN                                          -0.237737
# lit_adverb_ratio                                          0.115349
# lit_VP -> VBD_NP                                          0.153325
# lit_ttr                                                  -0.193855
# lit_ADVP -> RB                                            0.140467
# lit_verb_noun_ratio                                       0.077277
# lit_words_not_in_dict_ratio                               0.307781
# lit_ROOT -> FRAG                                          0.112450
# lit_mattr                                                -0.228567
# lit_verb_ratio                                           -0.254807
# lit_verb_modal_ratio                                      0.263875
# lit_NP -> PRP                                             0.079785
# lit_propositional_density                                -0.225486
# lit_avg_sentence_length                                  -0.132801
# lit_brunets_index                                         0.074703
# lit_subordinate_coordinate_conjunction_ratio             -0.094871
# lit_VP -> VBG                                            -0.122090
# lit_n_unique_words                                       -0.132611
# lit_avg_n_words_in_NP                                    -0.037438
# lit_n_words                                              -0.029816
# lit_NP_ratio                                              0.040197
#
#                                               Impoverished Vocabulary  \
# lit_avg_word_length                                         -0.518173
# lit_verb_present_participle_ratio                           -0.406114
# lit_pronoun_noun_ratio                                       0.452605
# lit_determiner_ratio                                        -0.378647
# lit_VP -> VBG_PP                                            -0.380079
# lit_preposition_ratio                                       -0.389140
# lit_honores_statistic                                       -0.346351
# lit_noun_ratio                                              -0.379807
# lit_PP_ratio                                                -0.367363
# lit_flesch_kincaid                                          -0.411763
# lit_VP_ratio                                                -0.365385
# lit_content_density                                         -0.310316
# lit_pronoun_ratio                                            0.359861
# lit_PRP_ratio                                                0.326407
# lit_personal_pronoun_ratio                                   0.326934
# lit_verb_third_person_singular_ratio                        -0.301623
# lit_avg_distance_between_utterances                          0.306477
# lit_prop_utterance_dist_below_05                            -0.292875
# lit_INTJ -> UH                                               0.255861
# lit_NP -> DT_NN                                             -0.308101
# lit_adverb_ratio                                             0.325242
# lit_VP -> VBD_NP                                             0.259236
# lit_ttr                                                     -0.209833
# lit_ADVP -> RB                                               0.225475
# lit_verb_noun_ratio                                          0.286802
# lit_words_not_in_dict_ratio                                  0.162776
# lit_ROOT -> FRAG                                             0.194348
# lit_mattr                                                   -0.239621
# lit_verb_ratio                                              -0.144562
# lit_verb_modal_ratio                                         0.161597
# lit_NP -> PRP                                                0.137171
# lit_propositional_density                                   -0.151519
# lit_avg_sentence_length                                     -0.242279
# lit_brunets_index                                            0.090464
# lit_subordinate_coordinate_conjunction_ratio                -0.141415
# lit_VP -> VBG                                               -0.092583
# lit_n_unique_words                                          -0.165000
# lit_avg_n_words_in_NP                                       -0.062589
# lit_n_words                                                 -0.024734
# lit_NP_ratio                                                 0.059164
#
#                                               Discourse Impairment  \
# lit_avg_word_length                                      -0.551835
# lit_verb_present_participle_ratio                        -0.398603
# lit_pronoun_noun_ratio                                    0.417032
# lit_determiner_ratio                                     -0.406191
# lit_VP -> VBG_PP                                         -0.328119
# lit_preposition_ratio                                    -0.334517
# lit_honores_statistic                                    -0.361829
# lit_noun_ratio                                           -0.418440
# lit_PP_ratio                                             -0.349880
# lit_flesch_kincaid                                       -0.348726
# lit_VP_ratio                                             -0.259634
# lit_content_density                                      -0.358080
# lit_pronoun_ratio                                         0.398334
# lit_PRP_ratio                                             0.362166
# lit_personal_pronoun_ratio                                0.361555
# lit_verb_third_person_singular_ratio                     -0.320991
# lit_avg_distance_between_utterances                       0.282279
# lit_prop_utterance_dist_below_05                         -0.281945
# lit_INTJ -> UH                                            0.306770
# lit_NP -> DT_NN                                          -0.244789
# lit_adverb_ratio                                          0.272793
# lit_VP -> VBD_NP                                          0.297597
# lit_ttr                                                  -0.263848
# lit_ADVP -> RB                                            0.257678
# lit_verb_noun_ratio                                       0.266431
# lit_words_not_in_dict_ratio                               0.168374
# lit_ROOT -> FRAG                                          0.231717
# lit_mattr                                                -0.105504
# lit_verb_ratio                                           -0.106413
# lit_verb_modal_ratio                                      0.221028
# lit_NP -> PRP                                             0.256876
# lit_propositional_density                                -0.122692
# lit_avg_sentence_length                                  -0.142032
# lit_brunets_index                                         0.177720
# lit_subordinate_coordinate_conjunction_ratio             -0.080131
# lit_VP -> VBG                                            -0.071593
# lit_n_unique_words                                       -0.024220
# lit_avg_n_words_in_NP                                    -0.086176
# lit_n_words                                               0.089678
# lit_NP_ratio                                             -0.023260
#
#                                               Word-Finding Difficulties (Anomia)  \
# lit_avg_word_length                                                    -0.543131
# lit_verb_present_participle_ratio                                      -0.498958
# lit_pronoun_noun_ratio                                                  0.474119
# lit_determiner_ratio                                                   -0.403669
# lit_VP -> VBG_PP                                                       -0.336542
# lit_preposition_ratio                                                  -0.303559
# lit_honores_statistic                                                  -0.379199
# lit_noun_ratio                                                         -0.415705
# lit_PP_ratio                                                           -0.300639
# lit_flesch_kincaid                                                     -0.227103
# lit_VP_ratio                                                           -0.332653
# lit_content_density                                                    -0.377772
# lit_pronoun_ratio                                                       0.420311
# lit_PRP_ratio                                                           0.374001
# lit_personal_pronoun_ratio                                              0.372108
# lit_verb_third_person_singular_ratio                                   -0.273555
# lit_avg_distance_between_utterances                                     0.155107
# lit_prop_utterance_dist_below_05                                       -0.195804
# lit_INTJ -> UH                                                          0.378928
# lit_NP -> DT_NN                                                        -0.203468
# lit_adverb_ratio                                                        0.297309
# lit_VP -> VBD_NP                                                        0.268551
# lit_ttr                                                                -0.324559
# lit_ADVP -> RB                                                          0.319020
# lit_verb_noun_ratio                                                     0.273096
# lit_words_not_in_dict_ratio                                             0.165109
# lit_ROOT -> FRAG                                                        0.243408
# lit_mattr                                                              -0.048585
# lit_verb_ratio                                                         -0.189835
# lit_verb_modal_ratio                                                    0.181945
# lit_NP -> PRP                                                           0.295070
# lit_propositional_density                                              -0.104293
# lit_avg_sentence_length                                                 0.002144
# lit_brunets_index                                                       0.253222
# lit_subordinate_coordinate_conjunction_ratio                           -0.073945
# lit_VP -> VBG                                                          -0.071134
# lit_n_unique_words                                                      0.027820
# lit_avg_n_words_in_NP                                                   0.038658
# lit_n_words                                                             0.148126
# lit_NP_ratio                                                            0.056634
#
#                                               Syntactic Simplification
# lit_avg_word_length                                          -0.544896
# lit_verb_present_participle_ratio                            -0.367318
# lit_pronoun_noun_ratio                                        0.296077
# lit_determiner_ratio                                         -0.376780
# lit_VP -> VBG_PP                                             -0.382708
# lit_preposition_ratio                                        -0.372583
# lit_honores_statistic                                        -0.278919
# lit_noun_ratio                                               -0.294149
# lit_PP_ratio                                                 -0.332860
# lit_flesch_kincaid                                           -0.402084
# lit_VP_ratio                                                 -0.351842
# lit_content_density                                          -0.297406
# lit_pronoun_ratio                                             0.236949
# lit_PRP_ratio                                                 0.274999
# lit_personal_pronoun_ratio                                    0.265577
# lit_verb_third_person_singular_ratio                         -0.290779
# lit_avg_distance_between_utterances                           0.337222
# lit_prop_utterance_dist_below_05                             -0.255745
# lit_INTJ -> UH                                                0.223063
# lit_NP -> DT_NN                                              -0.334814
# lit_adverb_ratio                                              0.244383
# lit_VP -> VBD_NP                                              0.236706
# lit_ttr                                                      -0.157784
# lit_ADVP -> RB                                                0.155051
# lit_verb_noun_ratio                                           0.160981
# lit_words_not_in_dict_ratio                                   0.170894
# lit_ROOT -> FRAG                                              0.167412
# lit_mattr                                                    -0.292902
# lit_verb_ratio                                               -0.211797
# lit_verb_modal_ratio                                          0.039863
# lit_NP -> PRP                                                 0.081319
# lit_propositional_density                                    -0.222030
# lit_avg_sentence_length                                      -0.228967
# lit_brunets_index                                             0.029435
# lit_subordinate_coordinate_conjunction_ratio                 -0.176886
# lit_VP -> VBG                                                -0.200465
# lit_n_unique_words                                           -0.186557
# lit_avg_n_words_in_NP                                        -0.053245
# lit_n_words                                                  -0.061500
# lit_NP_ratio                                                 -0.033963

# %%
row_subset.abs().max()
# Out:
# Semantic Paraphasias                  0.424565
# Impoverished Vocabulary               0.518173
# Discourse Impairment                  0.551835
# Word-Finding Difficulties (Anomia)    0.543131
# Syntactic Simplification              0.544896
# dtype: float64

# %%
from matplotlib import rc, font_manager
#from mpl_toolkits.axes_grid1.inset_locator import inset_axes

rc('font',**{'family':'serif','serif':['Times']})

fig, ax = plt.subplots(1, 1,figsize=(4,10))
im = ax.imshow(row_subset, cmap="coolwarm", vmin=-1, vmax=1)
ax.set_yticks(range(len(row_subset.index)), [re.match(r'lit_(.*)', c).group(1) for c in row_subset.index])
ax.set_xticks(range(len(row_subset.columns)), row_subset.columns, rotation=45, ha='right')
for (i, j), z in np.ndenumerate(row_subset):
    plt.text(j, i, '{:0.2f}'.format(z), ha='center', va='center', fontsize=5)
axins = ax.inset_axes(bounds=(0,-0.22,1,0.02)
                    #width="200%",  
                    #height="2%",
                    #loc='lower left',
                    #borderpad=-10
                   )
#plt.colorbar(orientation='horizontal',fraction=0.01, pad=0.2)
fig.colorbar(im, cax=axins, orientation="horizontal")

plt.tight_layout()
plt.subplots_adjust(left=0.7)
plt.savefig("plots/feature_correlation.pdf")
