# %%
import pandas as pd
import json

# %%
# Results of Validation of Word-Finding Difficulties against proxy measure disfluency_ratio
# Results based on config /configs/validation_against_proxy_measure/literature_gpt_and_disfluency_features.yaml

# %%
correlations = json.load(open("/Volumes/methlab/Students/Jonathan/results/runs/2024_kw32/20240809_1457_literature_gpt_and_disfluency_features_jsgk/feature_correlation.txt"))
correlations
# Out:
# {'disfl_n_fillers_fragments': {'disfl_n_fillers_fragments': 1.0,
#   'disfl_n_repetitions': 0.751830366497312,
#   'disfl_n_revisions': 0.6479830217241933,
#   'disfl_n_pause_short': 0.07864977317396482,
#   'disfl_n_pause_medium': 0.09179421527882005,
#   'disfl_n_pause_long': 0.011796665188836377,
#   'disfl_n_pauses': 0.10196752649098553,
#   'disfl_n_disfluencies': 0.8883377402938858,
#   'disfl_n_words': 0.5548165332266617,
#   'disfl_ratio_disfluencies': 0.588293734275781,
#   'lit_pronoun_noun_ratio': 0.1856899003299414,
#   'lit_verb_noun_ratio': 0.10742739750934331,
#   'lit_subordinate_coordinate_conjunction_ratio': 0.1102570384216442,
#   'lit_adverb_ratio': 0.05736637064450592,
#   'lit_noun_ratio': -0.24891765138026822,
#   'lit_verb_ratio': -0.14565078194327394,
#   'lit_pronoun_ratio': 0.18321236104963443,
#   'lit_personal_pronoun_ratio': 0.2038249790940273,
#   'lit_determiner_ratio': -0.13208857107020522,
#   'lit_preposition_ratio': 0.030252592009648815,
# ...

# %%
df = pd.Series(correlations['Word-Finding Difficulties (Anomia)']).sort_values(key=abs, ascending=False)
df
# Out:
# Word-Finding Difficulties (Anomia)              1.000000
# Impoverished Vocabulary                         0.845964
# Discourse Impairment                            0.825178
# Syntactic Simplification                        0.770499
# Semantic Paraphasias                            0.643776
# disfl_ratio_disfluencies                        0.634723
# disfl_n_disfluencies                            0.573744
# lit_avg_word_length                            -0.540210
# disfl_n_repetitions                             0.501800
# lit_pronoun_noun_ratio                          0.490881
# lit_verb_present_participle_ratio              -0.463799
# disfl_n_revisions                               0.434050
# lit_noun_ratio                                 -0.432054
# lit_pronoun_ratio                               0.420702
# disfl_n_pauses                                  0.418286
# disfl_n_fillers_fragments                       0.412073
# ...

# %%
# Result: Correlation of 0.63, which is higher than with any other linguistic feature
